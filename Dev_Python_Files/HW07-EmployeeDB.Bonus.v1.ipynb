# %%
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 


import psycopg2 as pg
import numpy as np
import pandas as pd

from cred_user import username
from cred_p import pgpass
from cred_host import host_loc
from cred_port import cred_port

# %%
db = "HW07 Employee DB"

# %%
connection = pg.connect(user=username,
                                  password=pgpass,
                                  host=host_loc,
                                  port=cred_port,
                                  database=db)

# %%
df = pd.read_sql_query('select * from "titles"', connection)

# %%
df
# Out:
#         emp_no               title   from_date     to_date
# 0        10001     Senior Engineer  1986-06-26  9999-01-01
# 1        10002               Staff  1996-08-03  9999-01-01
# 2        10003     Senior Engineer  1995-12-03  9999-01-01
# 3        10004            Engineer  1986-12-01  1995-12-01
# 4        10004     Senior Engineer  1995-12-01  9999-01-01
# 5        10005        Senior Staff  1996-09-12  9999-01-01
# 6        10005               Staff  1989-09-12  1996-09-12
# 7        10006     Senior Engineer  1990-08-05  9999-01-01
# 8        10007        Senior Staff  1996-02-11  9999-01-01
# 9        10007               Staff  1989-02-10  1996-02-11
# 10       10008  Assistant Engineer  1998-03-11  2000-07-31
# 11       10009  Assistant Engineer  1985-02-18  1990-02-18
# 12       10009            Engineer  1990-02-18  1995-02-18
# 13       10009     Senior Engineer  1995-02-18  9999-01-01
# 14       10010            Engineer  1996-11-24  9999-01-01
# ...

# %%
from sqlalchemy import create_engine
eng = create_engine('postgresql+psycopg2://'+ username +':' + pgpass + '@localhost:5432/HW07 Employee DB')
conn = eng.connect()


#from sqlalchemy import create_engine
#engine = create_engine('postgresql+psycopg2://user:password@hostname/database_name')

# %%
print(eng.table_names())
# Out:
# ['departments', 'employees', 'dept_emp', 'dept_mgr', 'salaries', 'titles']

# %%
df2 = pd.DataFrame(pd.read_sql_query('select * from "departments"', conn))

# %%
df2
# Out:
#   dpt_no            dpt_name
# 0   d001           Marketing
# 1   d002             Finance
# 2   d003     Human Resources
# 3   d004          Production
# 4   d005         Development
# 5   d006  Quality Management
# 6   d007               Sales
# 7   d008            Research
# 8   d009    Customer Service
